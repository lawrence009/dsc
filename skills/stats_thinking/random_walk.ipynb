# %% [markdown]
# # Hacker Statistics
#
# * [Intermediate Python](https://learn.datacamp.com/courses/intermediate-python)

# %% [markdown]
# use hacker statistics to calculate your chances of winning a bet. Use random number generators, loops, and Matplotlib to gain a competitive edge!

# %% [markdown]
# Empire State simulation
#
# Roll a dice:
#
# - 1 or 2: 1 step down
# - 3, 4, or 5: 1 step up
# - 6: roll again and take the number of steps of the roll
# - Can't go below step 0
# - 0.1 % chance of falling down the stairs
# - Bet: you'll reach step 60

# %%
import numpy as np

np.random.seed(49)

# %%
def random_walk():
    
    # Initialize random_walk
    random_walk = [0]

    for x in range(100):
        # Set step: last element in random_walk
        step = random_walk[-1]

        # Roll the dice
        dice = np.random.randint(1,7)

        # Determine next step
        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)
        
        # Implement clumsiness
        if np.random.rand() <= .001:
            step = 0

        # append next_step to random_walk
        random_walk.append(step)
        
    return random_walk

# Print random_walk
print(random_walk())
# Out:
# [0, 1, 6, 12, 11, 12, 13, 14, 15, 14, 16, 17, 18, 17, 21, 26, 27, 26, 25, 26, 32, 33, 34, 33, 36, 37, 38, 39, 40, 42, 41, 40, 41, 40, 39, 42, 41, 40, 41, 40, 39, 42, 43, 42, 43, 44, 43, 44, 45, 44, 43, 44, 43, 42, 43, 42, 43, 44, 45, 44, 43, 42, 43, 42, 43, 44, 45, 44, 45, 46, 45, 44, 45, 46, 49, 48, 49, 48, 49, 50, 55, 54, 55, 56, 57, 58, 59, 60, 61, 64, 65, 66, 72, 73, 74, 75, 74, 73, 74, 73, 72]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# Plot random_walk
_ = plt.plot(random_walk())

# %% [markdown]
# Simulate 10 walks

# %%
# initialize and populate all_walks
all_walks = []
for i in range(10) :
    all_walks.append(random_walk())
    
# Convert all_walks to Numpy array: np_aw
np_aw = np.array(all_walks)

# Plot np_aw and show
plt.plot(np_aw)
plt.show()

# Clear the figure
plt.clf()

# Transpose np_aw: np_aw_t
np_aw_t = np.transpose(np_aw)

# Plot np_aw_t and show
plt.plot(np_aw_t)
plt.show()

# %% [markdown]
# Plot the distribution
#
# All these fancy visualizations have put us on a sidetrack. We still have to solve the million-dollar problem: What are the odds that you'll reach 60 steps high on the Empire State Building?

# %%
all_walks = [random_walk() for i in range(100)]


# Create and plot np_aw_t
np_aw_t = np.transpose(np.array(all_walks))

# Select last row from np_aw_t: ends
ends = np_aw_t[-1,:]

# Plot histogram of ends, display plot
_ = plt.hist(ends, density=False)

# %%
sum(ends > 60) / 100
# Out:
# 0.76
